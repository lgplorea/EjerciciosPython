# %% [markdown]
# <a href="https://colab.research.google.com/github/lgplorea/EjerciciosPython/blob/main/EDAempresasUnicornio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos bibliotecas y módulos de python pertinentes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# Cargamos el conjunto de datos, tiene un formato csv y contiene datos sobre empresas unicornio

# %%
# Cargar los datos del archivo en un DataFrame y guardaremos en una variable.
companies = pd.read_csv("Unicorn_Companies.csv")
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %% [markdown]
# Utilizaremos las propiedades Size de Dataframes para hacernos una idea del tamaño del conjunto de datos

# %%
companies.size
# Out:
# 10740

# %% [markdown]
# Determinaremos la forma del conjunto de datos. Identificaremos el número de filas y columnas del conjunto completo.
# Utilizaremos la propuedad shape.

# %%
companies.shape # 1074 filas y 10 columnas
# Out:
# (1074, 10)

# %% [markdown]
# Obtenemos información del conjunto.
# Incluyendo el tipo de dato de los valores de cada columna. Hay muchas formas de realizar esto, aquí utilizaremos .info

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %% [markdown]
# Pruebas estadísticas
# Esta función genera estadísticas para las columnas numéricas de un conjunto de datos.

# %%
companies.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %% [markdown]
# Convertir Date Joined a datatime

# %%
companies["Date Joined"] = pd.to_datetime(companies["Date Joined"])
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %%
companies["Year Joined"] = companies["Date Joined"].dt.year
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %% [markdown]
# Resultados y evaluación

# %%
companies_sample = companies.sample(n = 50, random_state = 42) # garantiza que la muestra aleatoria va a ser siempre la misma, para que cualquier operacion aleatoria sea reproducible, obteniendo mismo resultado

# %% [markdown]
# Visualizaremos el tiempo que tardaron estas empresas en conseguir el status de Unicornio

# %%
companies_sample["years_till_unicorn"] = companies.sample["Year Joined"]
