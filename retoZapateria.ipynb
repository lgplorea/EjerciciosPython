# %% [markdown]
# <a href="https://colab.research.google.com/github/lgplorea/EjerciciosPython/blob/main/retoZapateria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Eres el gerente de una tienda de zapatos y necesitas controlar tu inventario. Cada vez que vendes un par de zapatos, disminuyes tu inventario. Quieres tener un programa que te permita ingresar la cantidad inicial de pares de zapatos en tu tienda y luego, sucesivamente, te pregunte cuántos pares de zapatos se vendieron. El programa debe continuar preguntando cuántos pares de zapatos se vendieron hasta que el inventario llegue a cero. Finalmente, el programa debe decirte cuántas transacciones (ventas individuales) tuvieron lugar antes de que se acabara el inventario.
#
# Instrucciones
# Inicia con un inventario de X pares de zapatos (donde X es un número que ingresas).
# Pregunta al usuario cuántos pares de zapatos se vendieron.
# Deduce esa cantidad del inventario.
# Repite el proceso hasta que el inventario sea 0.
# Imprime el número total de transacciones realizadas.

# %%
inventario = input("¿Cuántos pares de zapatos hay en el inventario?")
inventario = int(inventario)
print(f"El inventario contiene {inventario} pares de zapatos")

transacciones = 0

while inventario > 0:
  if inventario <= 3:
    print("El inventario está casi vacío: CUIDADO")
  try:
    num_zapatos = int(input("¿Cuántos pares de zapatos se vendieron?"))
  except ValueError:
    print("Por favor, introduce un número válido")
    continue
  if num_zapatos > inventario:
    print("No hay suficientes zapatos. Solo hay", inventario, "pares de zapatos disponibles")
  else:
    inventario -= num_zapatos
    transacciones += 1
    print(f"El cliente ha pedido {num_zapatos} zapatos. El inventario ahora tiene {inventario} zapatos")
print("Inventario agotado. Vuelve mañana!")
print(f"Número total de transacciones realizadas: {transacciones}")
# Out:
# ¿Cuántos pares de zapatos hay en el inventario?5
# El inventario contiene 5 pares de zapatos
# ¿Cuántos pares de zapatos se vendieron?1
# El cliente ha pedido 1 zapatos. El inventario ahora tiene 4 zapatos
# ¿Cuántos pares de zapatos se vendieron?2
# El cliente ha pedido 2 zapatos. El inventario ahora tiene 2 zapatos
# El inventario está casi vacío: CUIDADO
# ¿Cuántos pares de zapatos se vendieron?2
# El cliente ha pedido 2 zapatos. El inventario ahora tiene 0 zapatos
# Inventario agotado. Vuelve mañana!
# Número total de transacciones realizadas: 3
